# %% [markdown]
# <a href="https://colab.research.google.com/github/zihoonkim/practice/blob/main/cnn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf

# 1장 x 가로 1920 픽셀 x 세로 1080 픽셀 x 3채널(빨, 초, 파)
pic = tf.zeros((1, 1920, 1080, 3))
print("입력 이미지 데이터:", pic.shape) ## (1920 x 1080 x 3 텐서)
pic_flatten_out = tf.keras.layers.Flatten()(pic)
print("이미지 데이터 값 개수: ", pic_flatten_out.shape) ## (1920 x 1080 x 3 텐서) = 6220800
print("\n")

single_conv_layer = tf.keras.layers.Conv2D(filters=1, # 1개 필터
                                    kernel_size=(5, 5),    # 5 x 5 크기 
                                    use_bias=False)    
single_conv_out = single_conv_layer(pic) ## 5 x 5 크기의 필터 한개를 지나
print("단일 필터 Convolution 레이어:", single_conv_layer.weights[0].shape)
print("단일 필터 Convolution 레이어의 파라미터 수:", single_conv_layer.count_params())
print("단일 필터 Convolution 결과 이미지:", single_conv_out.shape)
single_flatten_out = tf.keras.layers.Flatten()(single_conv_out)
print("단일 필터 Convolution 결과 이미지 데이터 수: ", single_flatten_out.shape)
print("\n")

multiple_conv_layer = tf.keras.layers.Conv2D(filters=16, # 16개 필터
                                    kernel_size=(5, 5),    # 5 x 5 크기
                                    use_bias=False)    
multiple_conv_out = multiple_conv_layer(pic) ## 5 x 5 크기의 필터 16를 지난다
print("16개 필터 Convolution 레이어:", multiple_conv_layer.weights[0].shape)
print("16개 필터 Convolution 레이어의 파라미터 수:", multiple_conv_layer.count_params())
print("16개 필터 Convolution 결과 이미지:", multiple_conv_out.shape)
multiple_flatten_out = tf.keras.layers.Flatten()(multiple_conv_out)
print("16개 필터 Convolution 결과 이미지 데이터 수:", multiple_flatten_out.shape)

print("-" * 20)

print("입력이미지 2개")
import tensorflow as tf

# 1장 x 가로 1920 픽셀 x 세로 1080 픽셀 x 3채널(빨, 초, 파)
pic = tf.zeros((2, 1920, 1080, 3))
print("입력 이미지 데이터:", pic.shape)
pic_flatten_out = tf.keras.layers.Flatten()(pic)
print("이미지 데이터 값 개수: ", pic_flatten_out.shape)
print("\n")

single_conv_layer = tf.keras.layers.Conv2D(filters=1, # 1개 필터
                                    kernel_size=(5, 5),    # 5 x 5 크기
                                    use_bias=False)    # bias에 대해서는 여기서는 설명하지 않습니다.
single_conv_out = single_conv_layer(pic)
print("단일 필터 Convolution 레이어:", single_conv_layer.weights[0].shape)
print("단일 필터 Convolution 레이어의 파라미터 수:", single_conv_layer.count_params())
print("단일 필터 Convolution 결과 이미지:", single_conv_out.shape)
single_flatten_out = tf.keras.layers.Flatten()(single_conv_out)
print("단일 필터 Convolution 결과 이미지 데이터 수: ", single_flatten_out.shape)
print("\n")

multiple_conv_layer = tf.keras.layers.Conv2D(filters=16, # 16개 필터
                                    kernel_size=(5, 5),    # 5 x 5 크기
                                    use_bias=False)    # bias에 대해서는 여기서는 설명하지 않습니다.
multiple_conv_out = multiple_conv_layer(pic)
print("16개 필터 Convolution 레이어:", multiple_conv_layer.weights[0].shape)
print("16개 필터 Convolution 레이어의 파라미터 수:", multiple_conv_layer.count_params())
print("16개 필터 Convolution 결과 이미지:", multiple_conv_out.shape)
multiple_flatten_out = tf.keras.layers.Flatten()(multiple_conv_out)
print("16개 필터 Convolution 결과 이미지 데이터 수:", multiple_flatten_out.shape)



print("-" * 20)
print("필터 갯수 2, 3, 4, 5, 10개")

single_conv_layer = tf.keras.layers.Conv2D(filters=1, # 1개 필터
                                    kernel_size=(5, 5),    # 5 x 5 크기
                                    use_bias=False)    # bias에 대해서는 여기서는 설명하지 않습니다.
single_conv_out = single_conv_layer(pic)
print("단일 필터 Convolution 레이어:", single_conv_layer.weights[0].shape)
print("단일 필터 Convolution 레이어의 파라미터 수:", single_conv_layer.count_params())
print("단일 필터 Convolution 결과 이미지:", single_conv_out.shape)
single_flatten_out = tf.keras.layers.Flatten()(single_conv_out)
print("단일 필터 Convolution 결과 이미지 데이터 수: ", single_flatten_out.shape)
print("\n")




single_conv_layer = tf.keras.layers.Conv2D(filters=2, # 2개 필터
                                    kernel_size=(5, 5),    # 5 x 5 크기
                                    use_bias=False)    # bias에 대해서는 여기서는 설명하지 않습니다.
single_conv_out = single_conv_layer(pic)
print("단일 필터 Convolution 레이어:", single_conv_layer.weights[0].shape)
print("단일 필터 Convolution 레이어의 파라미터 수:", single_conv_layer.count_params())
print("단일 필터 Convolution 결과 이미지:", single_conv_out.shape)
single_flatten_out = tf.keras.layers.Flatten()(single_conv_out)
print("단일 필터 Convolution 결과 이미지 데이터 수: ", single_flatten_out.shape)
print("\n")

single_conv_layer = tf.keras.layers.Conv2D(filters=3, # 3개 필터
                                    kernel_size=(5, 5),    # 5 x 5 크기
                                    use_bias=False)    # bias에 대해서는 여기서는 설명하지 않습니다.
single_conv_out = single_conv_layer(pic)
print("단일 필터 Convolution 레이어:", single_conv_layer.weights[0].shape)
print("단일 필터 Convolution 레이어의 파라미터 수:", single_conv_layer.count_params())
print("단일 필터 Convolution 결과 이미지:", single_conv_out.shape)
single_flatten_out = tf.keras.layers.Flatten()(single_conv_out)
print("단일 필터 Convolution 결과 이미지 데이터 수: ", single_flatten_out.shape)
print("\n")

single_conv_layer = tf.keras.layers.Conv2D(filters=4, # 4개 필터
                                    kernel_size=(5, 5),    # 5 x 5 크기
                                    use_bias=False)    # bias에 대해서는 여기서는 설명하지 않습니다.
single_conv_out = single_conv_layer(pic)
print("단일 필터 Convolution 레이어:", single_conv_layer.weights[0].shape)
print("단일 필터 Convolution 레이어의 파라미터 수:", single_conv_layer.count_params())
print("단일 필터 Convolution 결과 이미지:", single_conv_out.shape)
single_flatten_out = tf.keras.layers.Flatten()(single_conv_out)
print("단일 필터 Convolution 결과 이미지 데이터 수: ", single_flatten_out.shape)
print("\n")

single_conv_layer = tf.keras.layers.Conv2D(filters=5, # 5개 필터
                                    kernel_size=(5, 5),    # 5 x 5 크기
                                    use_bias=False)    # bias에 대해서는 여기서는 설명하지 않습니다.
single_conv_out = single_conv_layer(pic)
print("단일 필터 Convolution 레이어:", single_conv_layer.weights[0].shape)
print("단일 필터 Convolution 레이어의 파라미터 수:", single_conv_layer.count_params())
print("단일 필터 Convolution 결과 이미지:", single_conv_out.shape)
single_flatten_out = tf.keras.layers.Flatten()(single_conv_out)
print("단일 필터 Convolution 결과 이미지 데이터 수: ", single_flatten_out.shape)
print("\n")

multiple_conv_layer = tf.keras.layers.Conv2D(filters=16, # 10개 필터
                                    kernel_size=(5, 5),    # 5 x 5 크기
                                    use_bias=False)    # bias에 대해서는 여기서는 설명하지 않습니다.
multiple_conv_out = multiple_conv_layer(pic)
print("16개 필터 Convolution 레이어:", multiple_conv_layer.weights[0].shape)
print("16개 필터 Convolution 레이어의 파라미터 수:", multiple_conv_layer.count_params())
print("16개 필터 Convolution 결과 이미지:", multiple_conv_out.shape)
multiple_flatten_out = tf.keras.layers.Flatten()(multiple_conv_out)
print("16개 필터 Convolution 결과 이미지 데이터 수:", multiple_flatten_out.shape)
# Out:
# 입력 이미지 데이터: (1, 1920, 1080, 3)
# 이미지 데이터 값 개수:  (1, 6220800)
#
#
# 단일 필터 Convolution 레이어: (5, 5, 3, 1)
# 단일 필터 Convolution 레이어의 파라미터 수: 75
# 단일 필터 Convolution 결과 이미지: (1, 1916, 1076, 1)
# 단일 필터 Convolution 결과 이미지 데이터 수:  (1, 2061616)
#
#
# 16개 필터 Convolution 레이어: (5, 5, 3, 16)
# 16개 필터 Convolution 레이어의 파라미터 수: 1200
# 16개 필터 Convolution 결과 이미지: (1, 1916, 1076, 16)
# 16개 필터 Convolution 결과 이미지 데이터 수: (1, 32985856)
# --------------------
# 입력이미지 2개
# 입력 이미지 데이터: (2, 1920, 1080, 3)
# 이미지 데이터 값 개수:  (2, 6220800)
#
#
# 단일 필터 Convolution 레이어: (5, 5, 3, 1)
# 단일 필터 Convolution 레이어의 파라미터 수: 75
# 단일 필터 Convolution 결과 이미지: (2, 1916, 1076, 1)
# 단일 필터 Convolution 결과 이미지 데이터 수:  (2, 2061616)
#
#
# 16개 필터 Convolution 레이어: (5, 5, 3, 16)
# 16개 필터 Convolution 레이어의 파라미터 수: 1200
# 16개 필터 Convolution 결과 이미지: (2, 1916, 1076, 16)
# 16개 필터 Convolution 결과 이미지 데이터 수: (2, 32985856)
# --------------------
# 필터 갯수 2, 3, 4, 5, 10개
# 단일 필터 Convolution 레이어: (5, 5, 3, 1)
# 단일 필터 Convolution 레이어의 파라미터 수: 75
# 단일 필터 Convolution 결과 이미지: (2, 1916, 1076, 1)
# 단일 필터 Convolution 결과 이미지 데이터 수:  (2, 2061616)
#
#
# 단일 필터 Convolution 레이어: (5, 5, 3, 2)
# 단일 필터 Convolution 레이어의 파라미터 수: 150
# 단일 필터 Convolution 결과 이미지: (2, 1916, 1076, 2)
# 단일 필터 Convolution 결과 이미지 데이터 수:  (2, 4123232)
#
#
# 단일 필터 Convolution 레이어: (5, 5, 3, 3)
# 단일 필터 Convolution 레이어의 파라미터 수: 225
# 단일 필터 Convolution 결과 이미지: (2, 1916, 1076, 3)
# 단일 필터 Convolution 결과 이미지 데이터 수:  (2, 6184848)
#
#
# 단일 필터 Convolution 레이어: (5, 5, 3, 4)
# 단일 필터 Convolution 레이어의 파라미터 수: 300
# 단일 필터 Convolution 결과 이미지: (2, 1916, 1076, 4)
# 단일 필터 Convolution 결과 이미지 데이터 수:  (2, 8246464)
#
#
# 단일 필터 Convolution 레이어: (5, 5, 3, 5)
# 단일 필터 Convolution 레이어의 파라미터 수: 375
# 단일 필터 Convolution 결과 이미지: (2, 1916, 1076, 5)
# 단일 필터 Convolution 결과 이미지 데이터 수:  (2, 10308080)
#
#
# 16개 필터 Convolution 레이어: (5, 5, 3, 16)
# 16개 필터 Convolution 레이어의 파라미터 수: 1200
# 16개 필터 Convolution 결과 이미지: (2, 1916, 1076, 16)
# 16개 필터 Convolution 결과 이미지 데이터 수: (2, 32985856)

# %%
# 1장 x 가로 1920 픽셀 x 세로 1080 픽셀 x 3채널(빨, 초, 파)
pic = tf.zeros((1, 1920, 1080, 3))
print("입력 이미지 데이터:", pic.shape) ## (1920 x 1080 x 3 텐서)
pic_flatten_out = tf.keras.layers.Flatten()(pic)
print("이미지 데이터 값 개수: ", pic_flatten_out.shape) ## (1920 x 1080 x 3 텐서) = 6220800
print("\n")

single_conv_layer = tf.keras.layers.Conv2D(filters=1, # 1개 필터
                                    kernel_size=(5, 5),    # 5 x 5 크기 
                                    use_bias=False)    
single_conv_out = single_conv_layer(pic) ## 5 x 5 크기의 필터 한개를 지나
print("단일 필터 Convolution 레이어:", single_conv_layer.weights[0].shape)
print("단일 필터 Convolution 레이어의 파라미터 수:", single_conv_layer.count_params())
print("단일 필터 Convolution 결과 이미지:", single_conv_out.shape)
single_flatten_out = tf.keras.layers.Flatten()(single_conv_out)
print("단일 필터 Convolution 결과 이미지 데이터 수: ", single_flatten_out.shape)
print("\n")

multiple_conv_layer = tf.keras.layers.Conv2D(filters=16, # 16개 필터
                                    kernel_size=(5, 5),    # 5 x 5 크기
                                    use_bias=False)    
multiple_conv_out = multiple_conv_layer(pic) ## 5 x 5 크기의 필터 16를 지난다
print("16개 필터 Convolution 레이어:", multiple_conv_layer.weights[0].shape)
print("16개 필터 Convolution 레이어의 파라미터 수:", multiple_conv_layer.count_params())
print("16개 필터 Convolution 결과 이미지:", multiple_conv_out.shape)
multiple_flatten_out = tf.keras.layers.Flatten()(multiple_conv_out)
print("16개 필터 Convolution 결과 이미지 데이터 수:", multiple_flatten_out.shape)



print("\n")
print("\n")

# 1장 x 가로 1920 픽셀 x 세로 1080 픽셀 x 2채널
pic = tf.zeros((1, 1920, 1080, 2))
print("입력 이미지 데이터:", pic.shape) ## (1920 x 1080 x 2 텐서)
pic_flatten_out = tf.keras.layers.Flatten()(pic)
print("이미지 데이터 값 개수: ", pic_flatten_out.shape) 
print("\n")

single_conv_layer = tf.keras.layers.Conv2D(filters=1, # 1개 필터
                                    kernel_size=(5, 5),    # 5 x 5 크기 
                                    use_bias=False)    
single_conv_out = single_conv_layer(pic) ## 5 x 5 크기의 필터 한개를 지나
print("단일 필터 Convolution 레이어:", single_conv_layer.weights[0].shape)
print("단일 필터 Convolution 레이어의 파라미터 수:", single_conv_layer.count_params())
print("단일 필터 Convolution 결과 이미지:", single_conv_out.shape)
single_flatten_out = tf.keras.layers.Flatten()(single_conv_out)
print("단일 필터 Convolution 결과 이미지 데이터 수: ", single_flatten_out.shape)
print("\n")

multiple_conv_layer = tf.keras.layers.Conv2D(filters=16, # 16개 필터
                                    kernel_size=(5, 5),    # 5 x 5 크기
                                    use_bias=False)    
multiple_conv_out = multiple_conv_layer(pic) ## 5 x 5 크기의 필터 16를 지난다
print("16개 필터 Convolution 레이어:", multiple_conv_layer.weights[0].shape)
print("16개 필터 Convolution 레이어의 파라미터 수:", multiple_conv_layer.count_params())
print("16개 필터 Convolution 결과 이미지:", multiple_conv_out.shape)
multiple_flatten_out = tf.keras.layers.Flatten()(multiple_conv_out)
print("16개 필터 Convolution 결과 이미지 데이터 수:", multiple_flatten_out.shape)
# Out:
# 입력 이미지 데이터: (1, 1920, 1080, 3)
# 이미지 데이터 값 개수:  (1, 6220800)
#
#
# 단일 필터 Convolution 레이어: (5, 5, 3, 1)
# 단일 필터 Convolution 레이어의 파라미터 수: 75
# 단일 필터 Convolution 결과 이미지: (1, 1916, 1076, 1)
# 단일 필터 Convolution 결과 이미지 데이터 수:  (1, 2061616)
#
#
# 16개 필터 Convolution 레이어: (5, 5, 3, 16)
# 16개 필터 Convolution 레이어의 파라미터 수: 1200
# 16개 필터 Convolution 결과 이미지: (1, 1916, 1076, 16)
# 16개 필터 Convolution 결과 이미지 데이터 수: (1, 32985856)
#
#
#
#
# 입력 이미지 데이터: (1, 1920, 1080, 2)
# 이미지 데이터 값 개수:  (1, 4147200)
#
#
# 단일 필터 Convolution 레이어: (5, 5, 2, 1)
# 단일 필터 Convolution 레이어의 파라미터 수: 50
# 단일 필터 Convolution 결과 이미지: (1, 1916, 1076, 1)
# 단일 필터 Convolution 결과 이미지 데이터 수:  (1, 2061616)
#
#
# 16개 필터 Convolution 레이어: (5, 5, 2, 16)
# 16개 필터 Convolution 레이어의 파라미터 수: 800
# 16개 필터 Convolution 결과 이미지: (1, 1916, 1076, 16)
# 16개 필터 Convolution 결과 이미지 데이터 수: (1, 32985856)

# %%
pic = tf.zeros((1, 1920, 1080, 3))
print("입력 이미지 데이터:", pic.shape)
print('\n')

conv_layer = tf.keras.layers.Conv2D(filters=16, # 16개 필터
                                    kernel_size=(5, 5),    # 5 x 5 크기
                                    use_bias=False)    
conv_out = conv_layer(pic)
print("16개 필터 Convolution 결과 데이터:", conv_out.shape)
print('\n')

pool_layer = tf.keras.layers.MaxPool2D(pool_size=(2, 2), strides=(2, 2))
pool_out = pool_layer(conv_out)
print("Pooling 결과 데이터:", pool_out.shape)

pool_layer = tf.keras.layers.MaxPool2D(pool_size=(4, 4), strides=(4, 4))
pool_out = pool_layer(conv_out)
print("Pooling 결과 데이터:", pool_out.shape)
# Out:
# 입력 이미지 데이터: (1, 1920, 1080, 3)
#
#
# 16개 필터 Convolution 결과 데이터: (1, 1916, 1076, 16)
#
#
# Pooling 결과 데이터: (1, 958, 538, 16)
# Pooling 결과 데이터: (1, 479, 269, 16)
